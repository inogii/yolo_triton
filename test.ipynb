# %% [markdown]
# ```bash
# docker run --rm --gpus 0 -v /projects/demos/football_demo/triton/triton:/models -p 12000:12000 nvcr.io/nvidia/tritonserver:23.04-py3 tritonserver --model-repository=/models --http-port 12000
# ```

# %%
from ultralytics import YOLO
import torch
print(torch.cuda.is_available())

# Load models
player_tracking = YOLO('models/player_tracking.pt')
ball_tracking = YOLO('models/ball_tracking.pt')

player_tracking.to('cuda')
ball_tracking.to('cuda')

player_tracking_onnx = player_tracking.export(format="onnx", device="cuda", opset=18)
ball_tracking_onnx = ball_tracking.export(format="onnx", device="cuda", opset=18)
# Out:
# True
# Ultralytics 8.3.3 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla V100-PCIE-32GB, 32501MiB)
# YOLO11x summary (fused): 464 layers, 56,828,179 parameters, 0 gradients, 194.4 GFLOPs
#
# PyTorch: starting from 'models/player_tracking.pt' with input shape (1, 3, 1280, 1280) BCHW and output shape(s) (1, 5, 33600) (109.3 MB)
#
# ONNX: starting export with onnx 1.13.0 opset 18...
# ONNX: slimming with onnxslim 0.1.34...
# ONNX: simplifier failure: FLOAT8E4M3FN
# ONNX: export success ✅ 5.3s, saved as 'models/player_tracking.onnx' (217.5 MB)
#
# Export complete (6.2s)
# Results saved to /projects/demos/football_demo/triton/models
# Predict:         yolo predict task=detect model=models/player_tracking.onnx imgsz=1280
# Validate:        yolo val task=detect model=models/player_tracking.onnx imgsz=1280 data=/projects/demos/football_demo/demo_tuesday/finetune_yolo/yolov11/final_dataset/data.yaml
# Visualize:       https://netron.app
# Ultralytics 8.3.3 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla V100-PCIE-32GB, 32501MiB)
# YOLO11x summary (fused): 464 layers, 56,828,179 parameters, 0 gradients, 194.4 GFLOPs
#
# PyTorch: starting from 'models/ball_tracking.pt' with input shape (1, 3, 1280, 1280) BCHW and output shape(s) (1, 5, 33600) (109.2 MB)
#
# ONNX: starting export with onnx 1.13.0 opset 18...
# ONNX: slimming with onnxslim 0.1.34...
# ONNX: simplifier failure: FLOAT8E4M3FN
# ONNX: export success ✅ 5.5s, saved as 'models/ball_tracking.onnx' (217.5 MB)
#
# Export complete (6.4s)
# Results saved to /projects/demos/football_demo/triton/models
# Predict:         yolo predict task=detect model=models/ball_tracking.onnx imgsz=1280
# Validate:        yolo val task=detect model=models/ball_tracking.onnx imgsz=1280 data=yolo11_ball_dataset/data.yaml
# Visualize:       https://netron.app

# %%
# test out model usage
player_tracking_onnx = YOLO('models/player_tracking.onnx', task="detect")
# ball_tracking_onnx = YOLO('/projects/demos/football_demo/triton/models/ball_tracking/1/model.onnx', task="detect")
# player_tracking_onnx = YOLO('triton/player_tracking/1/model.onnx', task="detect")

frame = 'images/frame_1.jpg'

results = player_tracking_onnx(frame)
print(results)
# Out:
# Loading models/player_tracking.onnx for ONNX Runtime inference...
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 810.5ms
# Speed: 2.9ms preprocess, 810.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'player'}
# obb: None
# orig_img: array([[[ 50,  45,  46],
#         [ 47,  42,  43],
#         [ 55,  51,  50],
#         ...,
#         [ 79,  81,  81],
#         [ 72,  74,  74],
#         [ 67,  69,  69]],
#
#        [[ 52,  47,  48],
#         [ 46,  41,  42],
#         [ 50,  45,  46],
#         ...,
#         [ 75,  77,  78],
#         [ 72,  74,  75],
#         [ 68,  70,  71]],
#
#        [[ 50,  45,  47],
#         [ 46,  41,  42],
#         [ 48,  43,  44],
#         ...,
#         [ 61,  62,  66],
#         [ 61,  64,  68],
#         [ 64,  67,  71]],
#
#        ...,
#
#        [[ 85,  96,  86],
#         [ 83,  94,  84],
#         [ 81,  92,  82],
#         ...,
#         [ 58,  93,  83],
#         [ 58,  93,  83],
#         [ 58,  93,  83]],
#
#        [[ 97, 108, 100],
#         [ 95, 106,  98],
#         [ 93, 104,  96],
#         ...,
#         [ 57,  92,  82],
#         [ 57,  92,  82],
#         [ 57,  92,  82]],
#
#        [[100, 111, 103],
#         [ 98, 109, 101],
#         [ 96, 106, 100],
#         ...,
#         [ 54,  89,  79],
#         [ 54,  89,  79],
#         [ 54,  89,  79]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/projects/demos/football_demo/triton/images/frame_1.jpg'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.874135971069336, 'inference': 810.511589050293, 'postprocess': 1.6460418701171875}]

# %%
import onnx
# Load the model
model = onnx.load('/projects/demos/football_demo/triton/triton/ball_tracking/1/model.onnx')

# Convert the model to IR version 8
model.ir_version = 8

# Save the converted model
onnx.save(model, '/projects/demos/football_demo/triton/triton/ball_tracking/1/model_1.onnx')

# %%
from pathlib import Path

# Define paths
model_name = "ball_tracking"
triton_repo_path = Path("triton") 
triton_model_path = triton_repo_path / model_name

# Create directories
(triton_model_path / "1").mkdir(parents=True, exist_ok=True)
print(triton_model_path)
# Out:
# triton/ball_tracking

# %%
# test out model usage
ball_tracking_onnx = YOLO('triton/ball_tracking/1/model.onnx', task="detect")
# ball_tracking_onnx = YOLO('/projects/demos/football_demo/triton/models/ball_tracking/1/model.onnx', task="detect")
# player_tracking_onnx = YOLO('triton/player_tracking/1/model.onnx', task="detect")

frame = 'images/frame_1.jpg'
results = ball_tracking_onnx(frame)
print(results)
# Out:
# Loading triton/ball_tracking/1/model.onnx for ONNX Runtime inference...
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 (no detections), 775.4ms
# Speed: 2.9ms preprocess, 775.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'ball'}
# obb: None
# orig_img: array([[[ 50,  45,  46],
#         [ 47,  42,  43],
#         [ 55,  51,  50],
#         ...,
#         [ 79,  81,  81],
#         [ 72,  74,  74],
#         [ 67,  69,  69]],
#
#        [[ 52,  47,  48],
#         [ 46,  41,  42],
#         [ 50,  45,  46],
#         ...,
#         [ 75,  77,  78],
#         [ 72,  74,  75],
#         [ 68,  70,  71]],
#
#        [[ 50,  45,  47],
#         [ 46,  41,  42],
#         [ 48,  43,  44],
#         ...,
#         [ 61,  62,  66],
#         [ 61,  64,  68],
#         [ 64,  67,  71]],
#
#        ...,
#
#        [[ 85,  96,  86],
#         [ 83,  94,  84],
#         [ 81,  92,  82],
#         ...,
#         [ 58,  93,  83],
#         [ 58,  93,  83],
#         [ 58,  93,  83]],
#
#        [[ 97, 108, 100],
#         [ 95, 106,  98],
#         [ 93, 104,  96],
#         ...,
#         [ 57,  92,  82],
#         [ 57,  92,  82],
#         [ 57,  92,  82]],
#
#        [[100, 111, 103],
#         [ 98, 109, 101],
#         [ 96, 106, 100],
#         ...,
#         [ 54,  89,  79],
#         [ 54,  89,  79],
#         [ 54,  89,  79]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/projects/demos/football_demo/triton/images/frame_1.jpg'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.9401779174804688, 'inference': 775.4356861114502, 'postprocess': 0.7727146148681641}]

# %%
# Load the Triton Server model
from ultralytics import YOLO
model = YOLO("http://localhost:12000/player_tracking", task="detect")

# %%
while True:
    results = model.predict("images/frame_1.jpg", data="players.yaml")

# print(results)
# Out:
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 640.9ms
# Speed: 3.4ms preprocess, 640.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 747.7ms
# Speed: 3.8ms preprocess, 747.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 754.1ms
# Speed: 3.9ms preprocess, 754.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 818.9ms
# Speed: 2.9ms preprocess, 818.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 640.2ms
# Speed: 3.1ms preprocess, 640.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 647.2ms
# Speed: 3.0ms preprocess, 647.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 647.1ms
# Speed: 3.8ms preprocess, 647.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 681.3ms
# Speed: 3.1ms preprocess, 681.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 686.2ms
# Speed: 3.0ms preprocess, 686.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 642.2ms
# Speed: 3.7ms preprocess, 642.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 648.6ms
# Speed: 3.1ms preprocess, 648.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1
ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 699.6ms
# Speed: 3.8ms preprocess, 699.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 638.8ms
# Speed: 3.8ms preprocess, 638.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /projects/demos/football_demo/triton/images/frame_1.jpg: 640x640 19 players, 652.9ms
# Speed: 3.9ms preprocess, 652.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# KeyboardInterrupt
# 2024-11-06T16:46:51Z
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 while True:
# ----> 2     results = model.predict("images/frame_1.jpg", data="players.yaml")
#       4 # print(results)
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/ultralytics/engine/model.py:554, in Model.predict(self, source, stream, predictor, **kwargs)
#     552 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     553     self.predictor.set_prompts(prompts)
# --> 554 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/ultralytics/engine/predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/ultralytics/engine/predictor.py:254, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     252 # Inference
#     253 with profilers[1]:
# --> 254     preds = self.inference(im, *args, **kwargs)
#     255     if self.args.embed:
#     256         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/ultralytics/nn/autobackend.py:558, in AutoBackend.forward(self, im, augment, visualize, embed)
#     556 elif self.triton:
#     557     im = im.cpu().numpy()  # torch to numpy
# --> 558     y = self.model(im)
#     560 # TensorFlow (SavedModel, GraphDef, Lite, Edge TPU)
#     561 else:
#     562     im = im.cpu().numpy()
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/ultralytics/utils/triton.py:90, in TritonRemoteModel.__call__(self, *inputs)
#      87     infer_inputs.append(infer_input)
#      89 infer_outputs = [self.InferRequestedOutput(output_name) for output_name in self.output_names]
# ---> 90 outputs = self.triton_client.infer(model_name=self.endpoint, inputs=infer_inputs, outputs=infer_outputs)
#      92 return [outputs.as_numpy(output_name).astype(input_format) for output_name in self.output_names]
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/tritonclient/http/_client.py:1476, in InferenceServerClient.infer(self, model_name, inputs, model_version, outputs, request_id, sequence_id, sequence_start, sequence_end, priority, timeout, headers, query_params, request_compression_algorithm, response_compression_algorithm, parameters)
#    1473 else:
#    1474     request_uri = "v2/models/{}/infer".format(quote(model_name))
# -> 1476 response = self._post(
#    1477     request_uri=request_uri,
#    1478     request_body=request_body,
#    1479     headers=headers,
#    1480     query_params=query_params,
#    1481 )
#    1482 _raise_if_error(response)
#    1484 return InferResult(response, self._verbose)
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/tritonclient/http/_client.py:296, in InferenceServerClient._post(self, request_uri, request_body, headers, query_params)
#     293     print("POST {}, headers {}\n{}".format(request_uri, headers, request_body))
#     295 if headers is not None:
# --> 296     response = self._client_stub.post(
#     297         request_uri=request_uri, body=request_body, headers=headers
#     298     )
#     299 else:
#     300     response = self._client_stub.post(
#     301         request_uri=request_uri, body=request_body
#     302     )
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/geventhttpclient/client.py:272, in HTTPClient.post(self, request_uri, body, headers)
#     271 def post(self, request_uri, body=u'', headers=None):
# --> 272     return self.request(METHOD_POST, request_uri, body=body, headers=headers)
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/geventhttpclient/client.py:253, in HTTPClient.request(self, method, request_uri, body, headers)
#     250     raise e
#     252 try:
# --> 253     response = HTTPSocketPoolResponse(sock, self._connection_pool,
#     254                                       block_size=self.block_size, method=method.upper(), headers_type=self.headers_type)
#     255 except HTTPConnectionClosed as e:
#     256     # connection is released by the response itself
#     257     if attempts_left > 0:
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/geventhttpclient/response.py:292, in HTTPSocketPoolResponse.__init__(self, sock, pool, **kw)
#     290 def __init__(self, sock, pool, **kw):
#     291     self._pool = pool
# --> 292     super(HTTPSocketPoolResponse, self).__init__(sock, **kw)
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/geventhttpclient/response.py:164, in HTTPSocketResponse.__init__(self, sock, block_size, method, **kw)
#     162 self._sock = sock
#     163 self.block_size = block_size
# --> 164 self._read_headers()
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/geventhttpclient/response.py:184, in HTTPSocketResponse._read_headers(self)
#     182 while not self.headers_complete:
#     183     try:
# --> 184         data = self._sock.recv(self.block_size)
#     185         self.feed(data)
#     186         # depending on gevent version we get a conn reset or no data
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/gevent/_socketcommon.py:662, in SocketMixin.recv(self, *args)
#     660     # QQQ without clearing exc_info test__refcount.test_clean_exit fails
#     661     exc_clear() # Python 2
# --> 662 self._wait(self._read_event)
#
# File src/gevent/_hub_primitives.py:317, in gevent._gevent_c_hub_primitives.wait_on_socket()
#
# File src/gevent/_hub_primitives.py:322, in gevent._gevent_c_hub_primitives.wait_on_socket()
#
# File src/gevent/_hub_primitives.py:313, in gevent._gevent_c_hub_primitives._primitive_wait()
#
# File src/gevent/_hub_primitives.py:314, in gevent._gevent_c_hub_primitives._primitive_wait()
#
# File src/gevent/_hub_primitives.py:46, in gevent._gevent_c_hub_primitives.WaitOperationsGreenlet.wait()
#
# File src/gevent/_hub_primitives.py:46, in gevent._gevent_c_hub_primitives.WaitOperationsGreenlet.wait()
#
# File src/gevent/_hub_primitives.py:55, in gevent._gevent_c_hub_primitives.WaitOperationsGreenlet.wait()
#
# File src/gevent/_waiter.py:154, in gevent._gevent_c_waiter.Waiter.get()
#
# File src/gevent/_greenlet_primitives.py:61, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src/gevent/_greenlet_primitives.py:61, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src/gevent/_greenlet_primitives.py:65, in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# File src/gevent/_gevent_c_greenlet_primitives.pxd:35, in gevent._gevent_c_greenlet_primitives._greenlet_switch()
#
# KeyboardInterrupt:

# %%
import contextlib
import subprocess
import time

from tritonclient.http import InferenceServerClient

# Define image https://catalog.ngc.nvidia.com/orgs/nvidia/containers/tritonserver
tag = "nvcr.io/nvidia/tritonserver:23.04-py3"  # 8.57 GB

# Pull the image
subprocess.call(f"docker pull {tag}", shell=True)
# Out:
# 23.04-py3: Pulling from nvidia/tritonserver
# 5544ebdc0c7b: Pulling fs layer
# 5c7458fe8983: Pulling fs layer
# 84fe6556776e: Pulling fs layer
# fd3b5161a370: Pulling fs layer
# f600d053e235: Pulling fs layer
# 2904faaa955b: Pulling fs layer
# 02e937dc172c: Pulling fs layer
# 674931146b3f: Pulling fs layer
# a7104e7e3962: Pulling fs layer
# dd2a18b53db3: Pulling fs layer
# f8c61d00c4fb: Pulling fs layer
# c012c2787074: Pulling fs layer
# 953e993ff650: Pulling fs layer
# fd3b5161a370: Waiting
# f600d053e235: Waiting
# d43c2dd3b915: Pulling fs layer
# a7104e7e3962: Waiting
# 2904faaa955b: Waiting
# f8c61d00c4fb: Waiting
# dd2a18b53db3: Waiting
# e27c48447f58: Pulling fs layer
# c012c2787074: Waiting
# d43c2dd3b915: Waiting
# 674931146b3f: Waiting
# 5c0a9d7fa918: Pulling fs layer
# 953e993ff650: Waiting
# 7558fdc023f4: Pulling fs layer
# 74cb7efc6ced: Pulling fs layer
# e27c48447f58: Waiting
# 5c0a9d7fa918: Waiting
# 7558fdc023f4: Waiting
# 867e3a24cb4d: Pulling fs layer
# a2b6974392b1: Pulling fs layer
# 867e3a24cb4d: Waiting
# ed3c4c0ef681: Pulling fs layer
# a2b6974392b1: Waiting
# 2d0e46615a6a: Pulling fs layer
# ed3c4c0ef681: Waiting
# 0cc252af77fc: Pulling fs layer
# bc63c1458844: Pulling fs layer
# 2d0e46615a6a: Waiting
# 0cc252af77fc: Waiting
# bc63c1458844: Waiting
# 5c7458fe8983: Verifying Checksum
# 5c7458fe8983: Download complete
# fd3b5161a370: Verifying Checksum
# 84fe6556776e: Verifying Checksum
# 84fe6556776e: Download complete
# 2904faaa955b: Verifying Checksum
# 2904faaa955b: Download complete
# 02e937dc172c: Verifying Checksum
# 02e937dc172c: Download complete
# 674931146b3f: Verifying Checksum
# 674931146b3f: Download complete
# 5544ebdc0c7b: Verifying Checksum
# 5544ebdc0c7b: Download complete
# a7104e7e3962: Verifying Checksum
# a7104e7e3962: Download complete
# 5544ebdc0c7b: Pull complete
# dd2a18b53db3: Verifying Checksum
# dd2a18b53db3: Download complete
# c012c2787074: Verifying Checksum
# c012c2787074: Download complete
# 5c7458fe8983: Pull complete
# 84fe6556776e: Pull complete
# fd3b5161a370: Pull complete
# 953e993ff650: Verifying Checksum
# 953e993ff650: Download complete
# d43c2dd3b915: Verifying Checksum
# d43c2dd3b915: Download complete
# e27c48447f58: Verifying Checksum
# e27c48447f58: Download complete
# 5c0a9d7fa918: Verifying Checksum
# 5c0a9d7fa918: Download complete
# f8c61d00c4fb: Verifying Checksum
# f8c61d00c4fb: Download complete
# f600d053e235: Verifying Checksum
# f600d053e235: Download complete
# 74cb7efc6ced: Verifying Checksum
# 74cb7efc6ced: Download complete
# a2b6974392b1: Verifying Checksum
# ed3c4c0ef681: Verifying Checksum
# ed3c4c0ef681: Download complete
# 867e3a24cb4d: Verifying Checksum
# 867e3a24cb4d: Download complete
# 0cc252af77fc: Verifying Checksum
# 0cc252af77fc: Download complete
# bc63c1458844: Verifying Checksum
# bc63c1458844: Download complete
# f600d053e235: Pull complete
# 2904faaa955b: Pull complete
# 02e937dc172c: Pull complete
# 674931146b3f: Pull complete
# a7104e7e3962: Pull complete
# dd2a18b53db3: Pull complete
# f8c61d00c4fb: Pull complete
# c012c2787074: Pull complete
# 953e993ff650: Pull complete
# d43c2dd3b915: Pull complete
# e27c48447f58: Pull complete
# 5c0a9d7fa918: Pull complete
# 7558fdc023f4: Verifying Checksum
# 7558fdc023f4: Download complete
# 7558fdc023f4: Pull complete
# 74cb7efc6ced: Pull complete
# 867e3a24cb4d: Pull complete
# a2b6974392b1: Pull complete
# ed3c4c0ef681: Pull complete
# 2d0e46615a6a: Retrying in 5 seconds
# 2d0e46615a6a: Retrying in 4 seconds
# 2d0e46615a6a: Retrying in 3 seconds
# 2d0e46615a6a: Retrying in 2 seconds
# 2d0e46615a6a: Retrying in 1 second
# 2d0e46615a6a: Verifying Checksum
# 2d0e46615a6a: Download complete
# 2d0e46615a6a: Pull complete
# 0cc252af77fc: Pull complete
# bc63c1458844: Pull complete
# Digest: sha256:ab1113741fc7ed5127a6b16bbcc70cee05f5ced285cd9f9a9fb0f42bc6d9daaa
# Status: Downloaded newer image for nvcr.io/nvidia/tritonserver:23.04-py3
# nvcr.io/nvidia/tritonserver:23.04-py3
# 0

# %%
import contextlib
import subprocess
import time

from tritonclient.http import InferenceServerClient

# Define image https://catalog.ngc.nvidia.com/orgs/nvidia/containers/tritonserver
tag = "nvcr.io/nvidia/tritonserver:24.09-py3"  # 8.57 GB

# Pull the image
subprocess.call(f"docker pull {tag}", shell=True)

# Run the Triton server and capture the container ID
container_id = (
    subprocess.check_output(
        f"docker run -d --rm --gpus 0 -v {triton_repo_path}:/models -p 8000:8000 {tag} tritonserver --model-repository=/models",
        shell=True,
    )
    .decode("utf-8")
    .strip()
)

# Wait for the Triton server to start
triton_client = InferenceServerClient(url="localhost:8000", verbose=False, ssl=False)

# Wait until model is ready
for _ in range(10):
    with contextlib.suppress(Exception):
        assert triton_client.is_model_ready(model_name)
        break
    time.sleep(1)

# %%
import tritonclient.http as httpclient
import numpy as np
from PIL import Image

# Load and preprocess the image
image_path = "images/frame_1.jpg"
image = Image.open(image_path).convert("RGB")
image = image.resize((640, 640))  # Resize based on model input requirements
input_data = np.array(image).astype(np.float32)
input_data = np.transpose(input_data, (2, 0, 1))  # Convert to CHW format if required by the model
input_data = np.expand_dims(input_data, axis=0)  # Add batch dimension

# Connect to Triton Server
triton_client = httpclient.InferenceServerClient(url="localhost:14600")

# Prepare inputs and outputs
inputs = [httpclient.InferInput("input_0", input_data.shape, "FP32")]
inputs[0].set_data_from_numpy(input_data)
outputs = [httpclient.InferRequestedOutput("output_0")]

# Run inference
response = triton_client.infer(model_name="ball_tracking", inputs=inputs, outputs=outputs)

# Retrieve results
output_data = response.as_numpy("output_0")
print("Inference output:", output_data)
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/geventhttpclient/connectionpool.py:163, in ConnectionPool.get_socket(self)
#     162 try:
# --> 163     return self._socket_queue.get(block=False)
#     164 except gevent.queue.Empty:
#
# File src/gevent/queue.py:375, in gevent._gevent_cqueue.Queue.get()
#
# File src/gevent/queue.py:391, in gevent._gevent_cqueue.Queue.get()
#
# File src/gevent/queue.py:359, in gevent._gevent_cqueue.Queue._Queue__get_or_peek()
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[4], line 22
#      19 outputs = [httpclient.InferRequestedOutput("output_0")]
#      21 # Run inference
# ---> 22 response = triton_client.infer(model_name="ball_tracking", inputs=inputs, outputs=outputs)
#      24 # Retrieve results
#      25 output_data = response.as_numpy("output_0")
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/tritonclient/http/_client.py:1476, in InferenceServerClient.infer(self, model_name, inputs, model_version, outputs, request_id, sequence_id, sequence_start, sequence_end, priority, timeout, headers, query_params, request_compression_algorithm, response_compression_algorithm, parameters)
#    1473 else:
#    1474     request_uri = "v2/models/{}/infer".format(quote(model_name))
# -> 1476 response = self._post(
#    1477     request_uri=request_uri,
#    1478     request_body=request_body,
#    1479     headers=headers,
#    1480     query_params=query_params,
#    1481 )
#    1482 _raise_if_error(response)
#    1484 return InferResult(response, self._verbose)
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/tritonclient/http/_client.py:296, in InferenceServerClient._post(self, request_uri, request_body, headers, query_params)
#     293     print("POST {}, headers {}\n{}".format(request_uri, headers, request_body))
#     295 if headers is not None:
# --> 296     response = self._client_stub.post(
#     297         request_uri=request_uri, body=request_body, headers=headers
#     298     )
#     299 else:
#     300     response = self._client_stub.post(
#     301         request_uri=request_uri, body=request_body
#     302     )
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/geventhttpclient/client.py:272, in HTTPClient.post(self, request_uri, body, headers)
#     271 def post(self, request_uri, body=u'', headers=None):
# --> 272     return self.request(METHOD_POST, request_uri, body=body, headers=headers)
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/geventhttpclient/client.py:226, in HTTPClient.request(self, method, request_uri, body, headers)
#     223 attempts_left = self._connection_pool.size + 1
#     225 while 1:
# --> 226     sock = self._connection_pool.get_socket()
#     227     try:
#     228         _request = request.encode()
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/geventhttpclient/connectionpool.py:166, in ConnectionPool.get_socket(self)
#     164 except gevent.queue.Empty:
#     165     try:
# --> 166         return self._create_socket()
#     167     except:
#     168         self._semaphore.release()
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/geventhttpclient/connectionpool.py:127, in ConnectionPool._create_socket(self)
#     124         raise
#     126 if first_error:
# --> 127     raise first_error
#     128 else:
#     129     raise RuntimeError(
#     130         "Cannot resolve %s:%s" % (self._host, self._port))
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/geventhttpclient/connectionpool.py:114, in ConnectionPool._create_socket(self)
#     112 try:
#     113     sock.settimeout(self.connection_timeout)
# --> 114     sock = self._connect_socket(sock, sock_info[-1])
#     115     self.after_connect(sock)
#     116     sock.settimeout(self.network_timeout)
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/geventhttpclient/connectionpool.py:136, in ConnectionPool._connect_socket(self, sock, address)
#     135 def _connect_socket(self, sock, address):
# --> 136     sock.connect(address)
#     137     self._setup_proxy(sock)
#     138     return sock
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/gevent/_socketcommon.py:586, in SocketMixin.connect(self, address)
#     572 """
#     573 Connect to *address*.
#     574
#    (...)
#     578     :func:`socket.inet_pton`.
#     579 """
#     580 # In the standard library, ``connect`` and ``connect_ex`` are implemented
#     581 # in C, and they both call a C function ``internal_connect`` to do the real
#     582 # work. This means that it is a visible behaviour difference to have our
#     583 # Python implementation of ``connect_ex`` simply call ``connect``:
#     584 # it could be overridden in a subclass or at runtime! Because of our exception handling,
#     585 # this can make a difference for known subclasses like SSLSocket.
# --> 586 self._internal_connect(address)
#
# File /projects/demos/football_demo/football-venv/lib/python3.10/site-packages/gevent/_socketcommon.py:630, in SocketMixin._internal_connect(self, address)
#     628 err = self.getsockopt(__socket__.SOL_SOCKET, __socket__.SO_ERROR)
#     629 if err:
# --> 630     raise _SocketError(err, strerror(err))
#     631 result = self._sock.connect_ex(address)
#     633 if not result or result == EISCONN:
#
# ConnectionRefusedError: [Errno 111] Connection refused
